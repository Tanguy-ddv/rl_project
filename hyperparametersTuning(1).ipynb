# %%
import itertools
import gym
from stable_baselines3 import PPO
import env.custom_hopper
from stable_baselines3.common.evaluation import evaluate_policy

def grid_search_ppo(env_name, total_timesteps, param_grid, n_eval_episodes=1000): #1000 since we want the test as reliable as possibile
    best_mean_reward = -float('inf')
    best_params = None
    all_results = []

    # Generate all combinations of hyperparameters
    keys, values = zip(*param_grid.items())
    all_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

    for params in all_combinations:
        print(f"Testing combination: {params}")

        # Create the environment
        env = gym.make(env_name)
        env.seed(0)  # Set seed for reproducibility

        try:
            # Create the PPO model with the current set of hyperparameters
            model = PPO(
                "MlpPolicy",
                env,
                learning_rate=params['learning_rate'],
                n_steps=params['n_steps'],
                batch_size=params['batch_size'],
                gamma=params['gamma'],
                clip_range=params['clip_range'],
                verbose=0,
                seed=0  # Set seed for reproducibility
            )

            # Train the model
            model.learn(total_timesteps=total_timesteps)

            # Evaluate the model
            mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_eval_episodes)
            print(f"Mean reward: {mean_reward} +/- {std_reward}")

            # Save the result
            all_results.append((params, mean_reward, std_reward))

            # Update best parameters if this is the best mean reward so far
            if mean_reward > best_mean_reward:
                best_mean_reward = mean_reward
                best_params = params

        finally:
            # Close the environment
            env.close()

    return best_params, best_mean_reward, all_results

param_grid = {
    'learning_rate': [1e-4, 3e-4, 1e-3],
    'n_steps': [2048, 4096],
    'batch_size': [64, 128],
    'gamma': [0.99, 0.995],
    'clip_range': [0.2, 0.3]
}

best_params, best_mean_reward, all_results = grid_search_ppo('CustomHopper-target-v0', total_timesteps=100000, param_grid=param_grid)
print("Best hyperparameters:", best_params)
print("Best mean reward:", best_mean_reward)
# Out:
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 2048, 'batch_size': 64, 'gamma': 0.99, 'clip_range': 0.2}
# /home/tanguy/Documents/rl_project/.conda/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward: 283.9247493470907 +/- 1.4900058121130269
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 2048, 'batch_size': 64, 'gamma': 0.99, 'clip_range': 0.3}
# Mean reward: 208.5073460499048 +/- 1.3638309364741126
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 2048, 'batch_size': 64, 'gamma': 0.995, 'clip_range': 0.2}
# Mean reward: 309.7309877593517 +/- 1.4228187268329222
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 2048, 'batch_size': 64, 'gamma': 0.995, 'clip_range': 0.3}
# Mean reward: 198.35272253763677 +/- 1.3115714345817509
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 2048, 'batch_size': 128, 'gamma': 0.99, 'clip_range': 0.2}
# Mean reward: 186.63160265135764 +/- 1.7858755947531058
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 2048, 'batch_size': 128, 'gamma': 0.99, 'clip_range': 0.3}
# Mean reward: 170.29410685443878 +/- 1.6791457169127826
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 2048, 'batch_size': 128, 'gamma': 0.995, 'clip_range': 0.2}
# Mean reward: 184.13233102303744 +/- 1.5897676511144225
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 2048, 'batch_size': 128, 'gamma': 0.995, 'clip_range': 0.3}
# Mean reward: 176.86245749008657 +/- 1.807431592506519
# Testing combination: {'learning_rate': 0.0001, 'n_steps': 4096, 'batch_size': 64, 'gamma': 0.99, 'clip_range': 0.2}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 66
#      56     return best_params, best_mean_reward, all_results
#      58 param_grid = {
#      59     'learning_rate': [1e-4, 3e-4, 1e-3],
#      60     'n_steps': [2048, 4096],
#    (...)
#      63     'clip_range': [0.2, 0.3]
#      64 }
# ---> 66 best_params, best_mean_reward, all_results = grid_search_ppo('CustomHopper-target-v0', total_timesteps=100000, param_grid=param_grid)
#      67 print("Best hyperparameters:", best_params)
#      68 print("Best mean reward:", best_mean_reward)
#
# Cell In[4], line 38, in grid_search_ppo(env_name, total_timesteps, param_grid, n_eval_episodes)
#      25 model = PPO(
#      26     "MlpPolicy",
#      27     env,
#    (...)
#      34     seed=0  # Set seed for reproducibility
#      35 )
#      37 # Train the model
# ---> 38 model.learn(total_timesteps=total_timesteps)
#      40 # Evaluate the model
#      41 mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_eval_episodes)
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:307, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 def learn(
#     298     self: SelfPPO,
#     299     total_timesteps: int,
#    (...)
#     304     progress_bar: bool = False,
#     305 ) -> SelfPPO:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:248, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     244 callback.on_training_start(locals(), globals())
#     246 while self.num_timesteps < total_timesteps:
# --> 248     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     250     if continue_training is False:
#     251         break
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:166, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     163 with th.no_grad():
#     164     # Convert to pytorch tensor or to TensorDict
#     165     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 166     actions, values, log_probs = self.policy(obs_tensor)
#     167 actions = actions.cpu().numpy()
#     169 # Rescale and perform action
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/stable_baselines3/common/policies.py:634, in ActorCriticPolicy.forward(self, obs, deterministic)
#     632 # Evaluate the values for the given observations
#     633 values = self.value_net(latent_vf)
# --> 634 distribution = self._get_action_dist_from_latent(latent_pi)
#     635 actions = distribution.get_actions(deterministic=deterministic)
#     636 log_prob = distribution.log_prob(actions)
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/stable_baselines3/common/policies.py:664, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     661 mean_actions = self.action_net(latent_pi)
#     663 if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 664     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     665 elif isinstance(self.action_dist, CategoricalDistribution):
#     666     # Here mean_actions are the logits before the softmax
#     667     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/stable_baselines3/common/distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)
#     161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/torch/distributions/normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/torch/distributions/distribution.py:66, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      64     continue  # skip checking lazily-constructed args
#      65 value = getattr(self, param)
# ---> 66 valid = constraint.check(value)
#      67 if not valid.all():
#      68     raise ValueError(
#      69         f"Expected parameter {param} "
#      70         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73         f"but found invalid values:\n{value}"
#      74     )
#
# File ~/Documents/rl_project/.conda/lib/python3.9/site-packages/torch/distributions/constraints.py:345, in _GreaterThan.check(self, value)
#     344 def check(self, value):
# --> 345     return self.lower_bound < value
#
# KeyboardInterrupt:
